# %%
# importing libraries
import requests 
import pandas as pd
import time

# %%
#api key
API_KEY="AIzaSyBdkPjqtzP_Y9P0G42UerXhNUVfiXRiKzc"
CHANNEL_ID="UCxZzSxuBaWqbHXkLb-kxRpw"

# %%
#make api call 
def api_page_call(base_url):
    base_url="https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&pageToken="
    page_token=""

    keep_reading=True
    while keep_reading:
        response=requests.get(base_url+page_token).json()
        print(response)

        if response.get('nextPageToken'):
            page_token=response["nextPageToken"]
        else:
            keep_reading=False

# %%
#function for video details like comment etc.
def get_video_details(video_id):
        url_2="https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&key="+API_KEY+"&part=statistics"
        response_2=requests.get(url_2).json()
        view_count=response_2['items'][0]['statistics']['viewCount']
        like_count=response_2['items'][0]['statistics']['likeCount']
        comment_count=response_2['items'][0]['statistics']['commentCount']
        return view_count,like_count,comment_count

# %%
#main function
def get_videos(df):
    #make api call 
    base_url="https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&pageToken="
    page_token=""
    #for looping through pages 
    
    keep_reading=True
    while keep_reading:
       
        response=requests.get(base_url+page_token).json()
        
        
        #for loop 
        for video in response['items']:
            if video['id']['kind']=='youtube#video':
                    video_id=video['id']['videoId']
                    video_title=video['snippet']['title']
                    video_title= str(video_title).replace("&amp;","")
                    upload_date=video['snippet']['publishTime']
                    upload_date=str(upload_date).split('T')[0]

                    view_count,like_count,comment_count =get_video_details(video_id)
                
                    #save data to the dataframe
                    df=df.append({
                        'video_id':video_id,
                        'video_title':video_title,
                        'upload_date':upload_date,
                        'view_count':view_count,
                        'like_count':like_count,
                        'comment_count':comment_count
                        },ignore_index=True
                    )

        if response.get('nextPageToken'):
            page_token=response["nextPageToken"]
          
            
        else:
            keep_reading=False
  
    
    return df

# %%
#main

#building our dataframe
df=pd.DataFrame(columns=['video_id','video_title','upload_date','view_count','like_count','comment_count'])
df=get_videos(df)

# %%
df
# Out:
#         video_id                                        video_title  \
# 0    pcY8kdyOzKE  Spearfishing in MASSIVE CAVES in Sicily, Italy 🇮🇹
# 1    4oMtvn2Aakw  DENTEX DREAM COMES TRUE AFTER 5 YEARS! Spearfi...
# 2    2-BILqR2Psg  NEW species in PORTUGAL 🇵🇹 Spearfishing Rugged...
# 3    rQ8q8z3bJ_8           End of spearfishing videos in the UK....
# 4    w2SGWIXpdng  When is it too COLD? Spearfishing Remote Arcti...
# 5    Jd71I5HMuVA  Spearfishing Dubai wrecks for Amberjack  Kingf...
# 6    L82__o5HtwY  SAFE  SIMPLE SPEARFISHING SETUP - Best rig for...
# 7    _PN3F85yIIE  Massive Crocodile HATES my drone - shore divin...
# 8    atg9b0jK3PY  CROCODILES LIVE HERE ...Barramundi spearfishin...
# 9    QS7ifP_k4j4  HOW DID THIS HAPPEN?! Massive Wahoo spearfishi...
# 10   CUNh6FcKu-E    It FINALLY happened! - 2021 Spearfishing review
# 11   qC51znhFTPU  What happened to the fish? Winter spearfishing...
# 12   UcvLtA6hB18        The Barradmundi Cave - Spearfishing #SHORTS
# ...
